# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#PyTorch.-Основы:-синтаксис,-torch.cuda-и-torch.autograd" data-toc-modified-id="PyTorch.-Основы:-синтаксис,-torch.cuda-и-torch.autograd-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><b>PyTorch. Основы: синтаксис, torch.cuda и torch.autograd</b></a></span><ul class="toc-item"><li><span><a href="#Задача-1" data-toc-modified-id="Задача-1-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Задача 1</a></span></li><li><span><a href="#Задача-2" data-toc-modified-id="Задача-2-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Задача 2</a></span></li><li><span><a href="#Задача-3" data-toc-modified-id="Задача-3-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Задача 3</a></span></li><li><span><a href="#Задача-4" data-toc-modified-id="Задача-4-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Задача 4</a></span></li><li><span><a href="#Задача-5" data-toc-modified-id="Задача-5-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Задача 5</a></span></li></ul></li></ul></div>

# %% [markdown]
# ---

# %% [markdown]
# <h2 style="text-align: center;"><b>PyTorch. Основы: синтаксис, torch.cuda и torch.autograd</b></h2>

# %% [markdown]
# <p style="align: center;"><img src="https://raw.githubusercontent.com/pytorch/pytorch/master/docs/source/_static/img/pytorch-logo-dark.png", width=400, height=300></p>

# %% [markdown]
# ---

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(42)

# %% [markdown]
# ### Задача 1

# %% [markdown]
# 1). Создайте два вещественных тензора: `a` размером (3, 4) и `b` размером (12,)
# 2). Создайте тензор `c`, являющийся тензором `b`, но размера (2, 2, 3)
# 3). Выведите первый столбец матрицы `a` с помощью индексации

# %%
a = torch.randn(3, 4)
b = torch.randn(12)

c = b.reshape(2, 2, 3)
print("a = ", a)
print("b = ", b)
print("c = ", c)
# Out:
# a =  tensor([[-1.5022,  0.8048, -0.9992, -1.6221],
#         [-0.6174,  2.8402,  0.4759,  0.5128],
#         [-1.1883,  0.7022,  0.1735, -1.3026]])
# b =  tensor([ 0.7678,  0.8373,  0.5754,  0.4287,  0.2458,  0.7246,  1.4066, -0.2627,
#         -2.6829,  1.5062, -1.0387, -2.8421])
# c =  tensor([[[ 0.7678,  0.8373,  0.5754],
#          [ 0.4287,  0.2458,  0.7246]],
#
#         [[ 1.4066, -0.2627, -2.6829],
#          [ 1.5062, -1.0387, -2.8421]]])

# %%
print(a[:, [0]])
# Out:
# tensor([[-1.5022],
#         [-0.6174],
#         [-1.1883]])

# %% [markdown]
# ### Задача 2

# %% [markdown]
# 1). Создайте два вещественных тензора: `a` размером (5, 2) и `b` размером (1,10)
# 2). Создайте тензор `c`, являющийся тензором `b`, но размера (5, 2)
# 3). Произведите все арифметические операции с тензорами `a` и `c`

# %%
a = torch.randn(5, 2)
b = torch.randn(1, 10)
print("a = ", a)
print("b = ", b)
# Out:
# a =  tensor([[ 0.8890, -0.8826],
#         [-0.7696, -0.2390],
#         [-1.4659, -1.0694],
#         [ 0.0797,  2.5361],
#         [-0.0637, -0.6537]])
# b =  tensor([[-1.9269, -0.9898,  0.3152,  0.3525, -0.8002, -0.1524,  1.3442,  0.0650,
#           0.5121,  0.4538]])

# %%
c = b.reshape(5, 2)
print("c = ", c)
# Out:
# c =  tensor([[-1.9269, -0.9898],
#         [ 0.3152,  0.3525],
#         [-0.8002, -0.1524],
#         [ 1.3442,  0.0650],
#         [ 0.5121,  0.4538]])

# %%
print(f'a + c = {a.add(c)}')
print(f'a - c = {a.sub(c)}')
print(f'a * c = {a.mul(c)}')
print(f'a / c = {a.div(c)}')
# Out:
# a + c = tensor([[-1.0380, -1.8724],
#         [-0.4544,  0.1135],
#         [-2.2660, -1.2218],
#         [ 1.4239,  2.6011],
#         [ 0.4484, -0.2000]])
# a - c = tensor([[ 2.8159,  0.1072],
#         [-1.0848, -0.5915],
#         [-0.6657, -0.9170],
#         [-1.2646,  2.4710],
#         [-0.5757, -1.1075]])
# a * c = tensor([[-1.7130,  0.8736],
#         [-0.2426, -0.0842],
#         [ 1.1729,  0.1630],
#         [ 0.1071,  0.1649],
#         [-0.0326, -0.2966]])
# a / c = tensor([[-0.4613,  0.8917],
#         [-2.4414, -0.6780],
#         [ 1.8320,  7.0172],
#         [ 0.0593, 39.0069],
#         [-0.1243, -1.4407]])

# %% [markdown]
# ### Задача 3

# %% [markdown]
# 1). Создайте тензор *целых чисел* `images` размерности (100, 200, 200, 3) (можно интерпретировать это как 100 картинок размера 200х200 с тремя цветовыми каналами, то есть 100 цветных изображений 200х200). Заполните его нулями

# %%
images = torch.zeros(100, 200, 200, 3, dtype=torch.int32)

# %% [markdown]
# 2). Сделайте так, чтобы у $i$-ой по порядку картинки была нарисована белая полоса толщиной два пикселя в строках, которые соответствуют номеру картинки. Например, у 3-ей по порядку картинки белая полоска будет занимать 6 и 7 строки, у 99 -- 198 и 199. Сделать белую строку можно, записав в ячейки тензора число 255 (по всем трём каналам). Выведите пару примеров с помощоью `pylot`

# %%
for i in range(100):
    start_row = 2 * i
    images[i, start_row:start_row+2, :, :] = 255

indices_to_show = [1, 2, 88]

fig, axes = plt.subplots(1, len(indices_to_show), figsize=(9, 3))
for idx, i in enumerate(indices_to_show):
    img = images[i].numpy() 
    axes[idx].imshow(img.astype('uint8'))  # ожидаются значения 0..255
    axes[idx].set_title(f'Image {i}')
    axes[idx].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# 3). Посчитайте среднее тензора `images` по 1-ой оси (по сути - средняя картинка), умножьте полученный тензор на 70. Нарисуйте с помощью `pyplot`, должна получиться серая картинка (при взятии среднего нужно привести тензор к float с помощью `.float()`, при отрисовке обратно к int с помощью `.int()`)

# %%
mean_image = images.float().mean(dim=0)
mean_scaled = mean_image * 70
mean_int = mean_scaled.round().int()
plt.imshow(mean_int.numpy())
plt.axis('off')
plt.title("Средняя картинка, умноженная на 70")
plt.show()

# %% [markdown]
# ### Задача 4

# %% [markdown]
# Перейдите на Google Colaboratory, чтобы работать с GPU. Загрузите туда этот ноутбук (Upload notebook)
# В Colab нажмите в меню сверху: Runtime -> Change Runtime Type -> GPU, где изначально стоит None
# Объявите тензор a размера (2, 3, 4) и тензор b размера (1, 8, 3) на GPU, иницилизируйте их случайно равномерно (.uniform_())
# Затем измените форму тензора b, чтобы она совпадала с формой тензора a, получите тензор c
# Переместите c на CPU, переместите a на CPU
# Оберните их в Variable()
# Объявите тензор L = torch.mean((c - a) ** 2) и посчитайте градиент L по c ( то есть  ∂𝐿∂𝑐)
#
# Выведите градиент L по c

# %%
from torch.autograd import Variable
a = torch.empty(2, 3, 4, device='cuda').uniform_()
b = torch.empty(1, 8, 3, device='cuda').uniform_()
c = b.view(2, 3, 4)
a_cpu = a.cpu()
c_cpu = c.cpu()
c_var = Variable(c_cpu, requires_grad=True)
a_var = Variable(a_cpu, requires_grad=False)

L = torch.mean((c_var - a_var) ** 2)
L.backward()
grad_c = c_var.grad
print("Градиент L по c:")
print(grad_c)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[43], line 5
#       1 from torch.autograd import Variable
#       2
#       3 device = torch.device('cuda')
#       4
# ----> 5 a = torch.empty(2, 3, 4, device=device).uniform_()
#       6 b = torch.empty(1, 8, 3, device=device).uniform_()
#       7 c = b.view(2, 3, 4)
#       8 a_cpu = a.cpu()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\cuda\__init__.py:478, in _lazy_init()
#     473     raise AssertionError(
#     474         "libcudart functions unavailable. It looks like you have a broken build?"
#     475     )
#     476 # This function throws if there's a driver initialization error, no GPUs
#     477 # are found or any other error occurs
# --> 478 torch._C._cuda_init()
#     479 # Some of the queued calls may reentrantly call _lazy_init();
#     480 # we need to just return without initializing in that case.
#     481 # However, we must not let any *other* threads in!
#     482 _tls.is_initializing = True
#
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx

# %% [markdown]
# ### Задача 5

# %% [markdown]
# Доработайте многослойную нейронную сеть из файла "4_3 mlp pytorch tasks".
