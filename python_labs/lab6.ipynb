# %% [markdown]
# ## Текстовые файлы в Python

# %% [markdown]
# 1) Ученые нашли табличку с текстом на языке племени Мумба-Юмба.
# Определите, сколько различных слов содержится в этом тексте. Словом
# считается последовательность непробельных символов идущих подряд, слова
# разделены одним или большим числом пробелов или символами конца строки.
# Большие и маленькие буквы считаются различными.

# %%
f = open("input1.txt", 'r')
words = f.read().split()
f.close()
print(len(set(words)))
# Out:
# 79936

# %% [markdown]
# 2) Дан файл, каждая строка которого может содержать одно или несколько
# целых чисел, разделенных одним или несколькими пробелами. Вычислите
# сумму чисел в каждой строке и выведите эти суммы через пробел (для каждой
# строки выводится сумма чисел в этой строке).

# %%
with open('input2.txt', 'r', encoding='utf-8') as f:
    lines = f.readlines()
    for line in lines:
        line = line.split()
        print(sum(int(x) for x in line))
f.close()
# Out:
# 34568147
# 255016
# 5617498
# 0
# 31397
# 17
# 10119996
# 111

# %% [markdown]
# 3) Дан текст на языке племени Мумба-Юмба. Выведите все слова,
# встречающиеся в тексте, разделяя их пробелом. Слова должны быть
# отсортированы по убыванию их количества появления в тексте, а при
# одинаковой частоте появления — в алфавитном порядке.

# %%
word_counts = {}
with open('input3.txt', 'r', encoding='utf-8') as f:
    words = f.read().split()
    for word in words:
        word_counts[word] = word_counts.get(word, 0) + 1
    sorted_words = sorted(word_counts.items(), key=lambda item: (-item[1], item[0]), reverse=False)
f.close()
print(sorted_words)
# Out:
# [('qzjijwnklo', 6), ('snlqkihyfdsr', 6), ('fitsjrsna', 5), ('fpn', 5), ('gwxivqvmm', 5), ('gywfhkjxlbesor', 5), ('lqzcspsgqdrnodhefktu', 5), ('mgofkir', 5), ('qxv', 5), ('tbqkprov', 5), ('uhkckkizcqlruqfei', 5), ('xmjknfygz', 5), ('zjecrsgusoxvkb', 5), ('abpsnguhzxxrxpax', 4), ('apjjzwocctrj', 4), ('aptvynrnbtr', 4), ('apzhfofihxmblhcasj', 4), ('avuzwvozf', 4), ('bnnbnwtoacsuinxji', 4), ('caw', 4), ('cgpe', 4), ('dmumnfkpyxsipgrh', 4), ('dojzeevpiodoe', 4), ('dxamcut', 4), ('ebmykcplnvoboq', 4), ('elzjhdxghg', 4), ('erejueqnhjhiwp', 4), ('etrbkcbgofelqwgmf', 4), ('falujgzqj', 4), ('fauau', 4), ('fdubwie', 4), ('firlr', 4), ('foms', 4), ('fpbvfrwi', 4), ('fplvjhf', 4), ('frfqkqvzriya', 4), ('ghgkqjuigcwmmtuaccj', 4), ('gnhmmfrb', 4), ('gnjvpddrchqrgbq', 4), ('hcraddxeqmklnmv', 4), ('hfyamck', 4), ('iaikqibshlj', 4), ('ivtswjkeaovuxn', 4), ('izgzanog', 4), ('jxkevdxpkox', 4), ('khvyzib', 4), ('kkaiyaiv', 4), ('ldpdpdxof', 4), ('lkohybndhiexyx', 4), ('lzhfxyq', 4), ('mankf', 4), ('mjppb
# ...
